# %% [markdown]
# # Python - Parte 1
#
# ## Sinyaxis básica

# %%
print("Hola mundo!")
# Out:
# Hola mundo!

# %% [markdown]
# ##Entradas y Salidas de datos
# ###Salidas: print()
# print() imprime en pantalla lo que le pasemos adentro del parentesis.

# %%
# Podemos imprimir los datos que querramos
print(8)          #numeros
print(8+5)        #operaciones
print("Matias")   #texto
# Out:
# 8
# 13
# Matias

# %%
#Podemos imprimir variables
nombre = "Pepe Sanchez"
edad = 35

#print("nombre")
print(nombre)
print(edad)
# Out:
# nombre
# Pepe Sanchez
# 35

# %%
# Puedo imprimir funciones/metodos/etc...
print(type(nombre))
print(type(edad))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ##Entradas: input()
# input() le pide al usuario que ingrese un valor y lo guarda como un string (texto)

# %%
nombre_usuario = input("Ingresa tu nombre: ")
print("hola " + nombre_usuario)
print(type(nombre_usuario))
# Out:
# Ingresa tu nombre: mati
# hola mati
# <class 'str'>

# %%
edad_usuario = input('Cual es tu edad? ')
print(type(edad_usuario))
# Out:
# Cual es tu edad? 26
# <class 'str'>

# %% [markdown]
# ##Comentarios
# Tenemos dos formas de comentar
#
#
# *   Utilizando #  - Por ejemplo: # Esto es un comentario de linea
# *   Utilizando """ - Por ejemplo: """ Esto es un comentario largo """

# %%
# Cualquier texto
print("todo ok")

"""
Ponemos
lo que
querramos
"""

print("fin")
# Out:
# todo ok
# fin

# %% [markdown]
# ## Variables en Python
# Python tiene cuatro tipos primitivos: enteros, flotantes, booleanos y cadenas o Strings.
#
# int() #Convierte a entero
#
# float() #Convierte a flotante
#
# bool() #Entrega False si es cero y True en el resto
#
# str() #Convierte a string

# %%
num1 = 250
num2 = 35.6
booleano = False
texto1 = "Pepe"
texto2 = 'Sanchez'

nombreApellido = ""
nombre_apellido = ""
NombreApellido = ""

num1 = float(num1)
print(num1)
# Out:
# 250.0

# %% [markdown]
# #OPERADORES
# Son símbolos que se aplican a uno o varios operandos en una expresión o instrucción con el fin de obtener cierto resultado
#
# Tipos de operadores
#
# 1) OPERADORES ARITMÉTICOS
# - suma +
# - resta -
# - multiplicación *
# - potencia **
# - división /
# - división entera //
# - módulo (resto de la división) %

# %%
numero = 10
print(numero + 10)
print(numero - 5)
print(numero * 2)
print(numero ** 2)
print(numero / 3)
print(numero // 3)
print(numero % 3)
# Out:
# 20
# 5
# 20
# 100
# 3.3333333333333335
# 3
# 1

# %% [markdown]
# También puedo usar * para strings (cadenas de texto)

# %%
nombre = "Matias"
apellido = "Escobar"
edad = 28

print(nombre + apellido)
print(nombre + " " + apellido)
print("hola "+nombre+". Tu edad es: ", edad)
print(nombre*3)

# %% [markdown]
# 2) OPERADORES DE ASIGNACIÓN
# Dada una variable, puedo asignarle un valor, escribiendo
#
#
# a = 5 # el operador **igual a**
#
#
# a += 4 # toma el valor actual de a y le suma 4 -> ahora vale 9
#
#
# a -= 3 # toma el valor actual de a y le resta 3 -> ahora vale 6
#
#
# a *= 2 # toma el valor actual de a y lo multiplica por 2 -> 12
#
#
# a /= 3
#
#
# a //=3
#
#
# a %= 3

# %%
a = 8
a += 2    # a = a + 2
print(a)
a -= 4    # a = a - 4
print(a)
a *= 3    # a = a * 3
print(a)
a /= 4    # a = a / 4
print(a)
# Out:
# 10
# 6
# 18
# 4.5

# %% [markdown]
# 3) OPERADORES RELACIONALES
# Devuelven un valor booleano. Se usan para crear los condicionales y poder alterar el flujo de nuestro programa
# Dados a y b
#
# a == b # si son iguales -> Devuelve True o False
#
# a != b # a no es igual a b
#
# a < b # a es menor que b
#
# a > b # a es mayor que b
#
# a <= b # a es menor o igual que b
#
# a >= b # a es mayor o igual que b

# %%
a = 10
b = 29

print(a == b)
print(a != b)
print(a >= b)
print(a < b)
# Out:
# False
# True
# False
# True

# %% [markdown]
# 4) OPERADORES LÓGICOS o BOOLEANOS
#
# and # evalúa si ambos operandos son True
#
# or # evalúa si al menos uno de los operandos es True
#
# not # cambia el valor del operando

# %%
a = 10
b = 29

print( a > 5 and b > 20)
print( a > 15 and b > 20)

print( a > 5 or b > 20)
print( a > 15 or b > 20)

print( not a > 15 and b > 20)
# Out:
# True
# False
# True
# True
# True

# %% [markdown]
# 5) OPERADORES DE PERTENENCIA
#
# Devuelve True o False dependiendo de si un elemento pertenece o no a una secuencia de datos
#
# IN
#
# NOT IN

# %%
mi_data = [4,5,6,10,22,65,"Matias", True]
print(99 in mi_data)
print(99 not in mi_data)
print("Mat" in mi_data)
print(True in mi_data)
# Out:
# False
# True
# False
# True
